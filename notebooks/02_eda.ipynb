# %%
#Imports & Data Load
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_breast_cancer

import matplotlib.pyplot as plt

# Plot prefs
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# Load dataset as DataFrame
data = load_breast_cancer(as_frame=True)
df    = data.frame.copy()
df["target"] = data.target         # append labels

print(df.shape)
df.head()
# Out:
# (569, 31)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
#Quick Overview
display(df.describe().T)

# Class balance
class_counts = df["target"].value_counts()
print("Class counts:\n", class_counts)
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title("Target Class Distribution")
plt.show()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
#Missing-Value Heatmap
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing-Value Map")
plt.show()

# %%
#  Feature Distributions (Density Plots)
numeric_cols = df.drop(columns="target").columns
df[numeric_cols].hist(bins=30, figsize=(18,12))
plt.suptitle("Feature Histograms", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Correlation Matrix
corr = df[numeric_cols].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(15,12))
sns.heatmap(corr, mask=mask, cmap="coolwarm", center=0,
            linewidths=0.5, cbar_kws={"shrink": .5})
plt.title("Feature Correlation (upper-triangle hidden)")
plt.show()

# %%
#MLflow Artifact Logging 
import mlflow
import os

notebook_path = "02_eda.ipynb"  # assumes notebook is in the current directory
if not os.path.exists(notebook_path):
    # Try with full path if running from a different directory
    notebook_path = os.path.basename(__file__) if "__file__" in globals() else "02_eda.ipynb"

with mlflow.start_run(run_name="eda"):
    mlflow.log_param("rows", df.shape[0])
    mlflow.log_param("cols", df.shape[1])
    if os.path.exists(notebook_path):
        mlflow.log_artifact(notebook_path, artifact_path="eda_notebook")
    else:
        print(f"Notebook file '{notebook_path}' not found, skipping artifact logging.")
    # Save plots as PNG + log_artifact if desired
